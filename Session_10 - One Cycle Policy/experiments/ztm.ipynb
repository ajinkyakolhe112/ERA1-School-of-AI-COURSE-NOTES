# %%
import torch
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit',
#  'torch']

# %%
dir(torch) # functions in torch 
vars(torch) # variables in torch
# Out:
# {'__name__': 'torch',
#  '__doc__': '\nThe torch package contains data structures for multi-dimensional\ntensors and defines mathematical operations over these tensors.\nAdditionally, it provides many utilities for efficient serialization of\nTensors and arbitrary types, and other useful utilities.\n\nIt has a CUDA counterpart, that enables you to run your tensor computations\non an NVIDIA GPU with compute capability >= 3.0.\n',
#  '__package__': 'torch',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f94916cda30>,
#  '__spec__': ModuleSpec(name='torch', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f94916cda30>, origin='/Users/ajinkya/opt/anaconda3/lib/python3.9/site-packages/torch/__init__.py', submodule_search_locations=['/Users/ajinkya/opt/anaconda3/lib/python3.9/site-packages/torch']),
#  '__path__': ['/Users/ajinkya/opt/anaconda3/lib/python3.9/site-packages/torch'],
# ...
